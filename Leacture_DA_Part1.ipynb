# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
"""Load data directory"""
dir_dataframe = 'D:\ix_onepy\Data\Data Excel'

# %%
dt_load = pd.read_excel(dir_dataframe + '/Data_CC_Cidanau_1048.xlsx')
dt_load.head()
# Out:
#    FID  Shape  Class       kategori  frci    Band_1    Band_2    Band_3  \
# 0  544  Point      1  Sangat Rendah   0.0  0.119028  0.096263  0.088627
# 1  684  Point      1  Sangat Rendah   0.0  0.113155  0.089109  0.072956
# 2  686  Point      1  Sangat Rendah   0.0  0.124964  0.104814  0.095479
# 3  723  Point      1  Sangat Rendah   0.0  0.120681  0.099382  0.089137
# 4  739  Point      1  Sangat Rendah   0.0  0.113995  0.090231  0.077047
#
#      Band_4    Band_5    Band_6    Band_7    Band_9      NDVI   SAVI_.5
# 0  0.067901  0.356388  0.246095  0.124561  0.001402  0.679930  0.468177
# 1  0.050277  0.299869  0.164176  0.080432  0.001548  0.712823  0.440381
# 2  0.100075  0.237620  0.215206  0.135871  0.001697  0.407305  0.246292
# 3  0.079335  0.288038  0.236145  0.133857  0.001737  0.568096  0.360923
# 4  0.051841  0.352246  0.195241  0.088700  0.001420  0.743417  0.498412

# %%
"""Correlation between two variable"""
corr = dt_load.corr()
corr
# Out:
#               FID     Class      frci    Band_1    Band_2    Band_3    Band_4  \
# FID      1.000000 -0.380763 -0.381986 -0.316407 -0.172373 -0.019611  0.166743
# Class   -0.380763  1.000000  0.995048 -0.215201 -0.347311 -0.562559 -0.559324
# frci    -0.381986  0.995048  1.000000 -0.219069 -0.352306 -0.567569 -0.566073
# Band_1  -0.316407 -0.215201 -0.219069  1.000000  0.972079  0.806368  0.730995
# Band_2  -0.172373 -0.347311 -0.352306  0.972079  1.000000  0.886358  0.856087
# Band_3  -0.019611 -0.562559 -0.567569  0.806368  0.886358  1.000000  0.869032
# Band_4   0.166743 -0.559324 -0.566073  0.730995  0.856087  0.869032  1.000000
# Band_5  -0.392356  0.120399  0.121991  0.071320 -0.032189  0.113807 -0.324676
# Band_6   0.007924 -0.642410 -0.649497  0.643150  0.730153  0.868136  0.768763
# Band_7   0.139211 -0.657948 -0.665333  0.660859  0.786764  0.860397  0.923438
# Band_9  -0.224343  0.174614  0.176600  0.385179  0.274284  0.086217 -0.005393
# NDVI    -0.279980  0.469599  0.474726 -0.539630 -0.678192 -0.616645 -0.909750
# SAVI_.5 -0.374728  0.325125  0.328875 -0.246206 -0.380041 -0.271234 -0.670957
#
#            Band_5    Band_6    Band_7    Band_9      NDVI   SAVI_.5
# FID     -0.392356  0.007924  0.139211 -0.224343 -0.279980 -0.374728
# Class    0.120399 -0.642410 -0.657948  0.174614  0.469599  0.325125
# frci     0.121991 -0.649497 -0.665333  0.176600  0.474726  0.328875
# Band_1   0.071320  0.643150  0.660859  0.385179 -0.539630 -0.246206
# Band_2  -0.032189  0.730153  0.786764  0.274284 -0.678192 -0.380041
# Band_3   0.113807  0.868136  0.860397  0.086217 -0.616645 -0.271234
# Band_4  -0.324676  0.768763  0.923438 -0.005393 -0.909750 -0.670957
# Band_5   1.000000  0.174256 -0.166017  0.190004  0.672209  0.917228
# Band_6   0.174256  1.000000  0.922458  0.002008 -0.514561 -0.182432
# Band_7  -0.166017  0.922458  1.000000 -0.059553 -0.787986 -0.517159
# Band_9   0.190004  0.002008 -0.059553  1.000000  0.085430  0.155502
# NDVI     0.672209 -0.514561 -0.787986  0.085430  1.000000  0.910749
# SAVI_.5  0.917228 -0.182432 -0.517159  0.155502  0.910749  1.000000

# %%
fig = plt.figure(figsize=(12,12))
plt.matshow(corr, cmap='RdBu', fignum=fig.number)
plt.xticks(range(len(corr.columns)), corr.columns, rotation='vertical');
plt.yticks(range(len(corr.columns)), corr.columns);

# %%
label = list(corr.columns)
label
# Out:
# ['FID',
#  'Class',
#  'frci',
#  'Band_1',
#  'Band_2',
#  'Band_3',
#  'Band_4',
#  'Band_5',
#  'Band_6',
#  'Band_7',
#  'Band_9',
#  'NDVI',
#  'SAVI_.5']

# %%
alpha = label
fig = plt.figure(figsize=(12,12))
# ax = fig.add_subplot(221)
cax = fig.matshow(corr, interpolation='nearest')
fig.colorbar(cax)

ax.set_xticklabels(['']+alpha)
ax.set_yticklabels(['']+alpha)

plt.show()
